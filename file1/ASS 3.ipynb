# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
import pandas as pd

# %% [markdown]
# QUESTION NO : 5

# %%
page = requests.get('https://www.cnbc.com/world/?region=world')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content,"html.parser")
soup

# %%
news_articles = soup.find_all('div', class_='Card-titleContainer')

# %%
headings = []
links = []

for article in news_articles:
    heading = article.find('a').text.strip()
    
    link = article.find('a')['href']
    
    headings.append(heading)
   
    links.append(link)

# %%
headings
# Out:
# ['S&P 500 is little changed to start the week as benchmark tries to build on records: Live updates',
#  "Britain's Labour Party pledges 'wealth creation' as it targets landslide election victory",
#  "UK's Sunak announces election pledges, looking to bounce back from D-Day gaffe",
#  'UK unemployment nears three-year high, wage growth firm as election looms',
#  "UK's populist right-wing party surges in popularity on Brexiteer Nigel Farage's return",
#  'UK PM Sunak attacks main rival as he languishes in election polls',
#  '‘We need to take action’: Iceland wants to shake up its tourism tax to better protect nature',
#  "Used EV price cliff keeps getting steeper as car buyers reject 'premium' label",
#  "Norway discovers Europe's largest deposit of rare earth metals",
#  "With EVs, Honda may be North America's most committed automaker, for the moment",
#  'The race to $25,000 EV has been won, at least in the used car market',
# ...

# %%
links
# Out:
# ['https://www.cnbc.com/2024/06/16/stock-market-today-live-updates.html',
#  'https://www.cnbc.com/2024/06/13/uk-general-election-2024-labour-publishes-manifesto-.html',
#  'https://www.cnbc.com/2024/06/11/conservative-manifesto-uks-rishi-sunak-announces-election-pledges.html',
#  'https://www.cnbc.com/2024/06/11/uk-unemployment-nears-three-year-high-as-election-approaches.html',
#  'https://www.cnbc.com/2024/06/06/uk-election-brexiteer-nigel-farages-return-boosts-uks-right-wing.html',
#  'https://www.cnbc.com/2024/06/04/uk-election-2024-sunak-and-starmer-clash-in-first-head-to-head-debate.html',
#  'https://www.cnbc.com/2024/06/17/iceland-wants-to-revamp-its-tourist-tax-policy-to-fight-overtourism.html',
#  'https://www.cnbc.com/2024/06/16/used-ev-price-crash-gets-deeper-with-premium-brand-idea-history.html',
#  'https://www.cnbc.com/2024/06/11/norway-discovers-europes-largest-deposit-of-rare-earth-metals.html',
# ...

# %%
dates = []

for i in soup.find_all('p',class_="RiverByline-datePublished"):
    dates.append(i.text)

dates
# Out:
# []

# %% [markdown]
# QUESTION NO : 6

# %%
page = requests.get('https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloaded-articles/')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content,"html.parser")
soup

# %%
authors = []

for i in soup.find_all('p',class_="article-authors"):
    authors.append(i.text)

authors
# Out:
# [' Tanha Talaviya |  Dhara Shah |  Nivedita Patel |  Hiteshri Yagnik |  Manan Shah',
#  ' Jinyuan Xu |  Baoxing Gu |  Guangzhao Tian',
#  ' Kirtan Jha |  Aalap Doshi |  Poojan Patel |  Manan Shah',
#  ' A. Subeesh |  C.R. Mehta',
#  ' Juzhong Tan |  Jie Xu',
#  ' V.G. Dhanya |  A. Subeesh |  N.L. Kushwaha |  Dinesh Kumar Vishwakarma |  T. Nagesh Kumar |  G. Ritika |  A.N. Singh',
#  ' Matteo Rizzo |  Matteo Marcuzzo |  Alessandro Zangari |  Andrea Gasparetto |  Andrea Albarelli',
#  ' Vijai Singh |  Namita Sharma |  Shikha Singh',
#  ' Ananda S. Paymode |  Vandana B. Malode',
#  ' Vilani Sachithra |  L.D.C.S. Subhashini',
#  ' P. Isaac Ritharson |  Kumudha Raimond |  X. Anitha Mary |  Jennifer Eunice Robert |  Andrew J',
#  ' Baoling Ma |  Zhixin Hua |  Yuchen Wen |  Hongxing Deng |  Yongjie Zhao |  Liuru Pu |  Huaibo Song',
#  ' Md Taimur Ahad |  Yan Li |  Bo Song |  Touhid Bhuiyan',
#  ' Punam Bedi |  Pushkar Gole',
#  ' Shwetha V |  Arnav Bhagwat |  Vijaya Laxmi',
# ...

# %%
titles = []

for i in soup.find_all('h2',class_="h5 article-title"):
    titles.append(i.text)

titles
# Out:
# ['\n\r\n                    Implementation of artificial intelligence in agriculture for optimisation of irrigation and application of pesticides and herbicides\r\n                \n',
#  '\n\r\n                    Review of agricultural IoT technology\r\n                \n',
#  '\n\r\n                    A comprehensive review on automation in agriculture using artificial intelligence\r\n                \n',
#  '\n\r\n                    Automation and digitization of agriculture using artificial intelligence and internet of things\r\n                \n',
#  '\n\r\n                    Applications of electronic nose (e-nose) and electronic tongue (e-tongue) in food quality-related properties determination: A review\r\n                \n',
#  '\n\r\n                    Deep learning based computer vision approaches for smart agricultural applications\r\n                \n',
#  '\n\r\n                    Fruit ripeness classification: A survey\r\n                \n',
# ...

# %%
dates = []

for i in soup.find_all('p',class_="article-date"):
    dates.append(i.text)

dates
# Out:
# ['2020',
#  '2022',
#  'June 2019',
#  '2021',
#  '2020',
#  '2022',
#  'March 2023',
#  '2020',
#  '2022',
#  'June 2023',
#  'March 2024',
#  'March 2024',
#  'September 2023',
#  '2021',
#  'June 2024',
#  'September 2023',
#  '2022',
#  '2022',
#  '2022',
#  '2020',
#  '2020',
#  '2022',
#  'June 2024',
#  '2022',
#  'December 2023']

# %% [markdown]
# QUESTION NO : 1

# %%
page = requests.get('https://www.imdb.com/list/ls056092300/')

# %%
page
# Out:
# <Response [403]>

# %% [markdown]
# QUESTION NO : 2

# %%
page = requests.get('https://www.patreon.com/coreyms')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content,"html.parser")
soup

# %%
headings = []

for i in soup.find_all('span',class_="post-title"):
    headings.append(i.text)

headings
# Out:
# []

# %%
posts = soup.find_all('div', class_=)

# %%
post_headings = []
post_dates = []
post_contents = []
post_likes = []

for post in posts:
    heading = post.find('h3', class_='post-title').text.strip()
    date = post.find('time').text.strip()
    content = post.find('div', class_='postCard-content').text.strip()
        
    youtube_link = post.find('a', class_='postCard-videoLink')
    if youtube_link:
        youtube_url = youtube_link['href']
           
    post_headings.append(heading)
    post_dates.append(date)
    post_contents.append(content)
    post_likes.append('Likes Count') 

post_headings
post_dates
post_contents
post_likes

# %% [markdown]
# QUESTION NO : 3

# %%
page = requests.get('https://www.nobroker.in/')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content,"html.parser")
soup

# %%
#class="heading-6 nb__2hf8o"
title = []

for i in soup.find_all('div',class_="heading-6"):
    title.append(i.text)

title
# Out:
# ['Properties & Flats for Sale',
#  'Flats for Rent',
#  'PG / Hostels',
#  'Flatmates',
#  'Miscellaneous',
#  'Commercial',
#  'New Projects & Plots',
#  'City Real Estate',
#  'Buy',
#  'Rent']

# %%
#class="nb__2EQjN"
dates = []

for i in soup.find_all('div',class_="nb__2EQjN"):
    dates.append(i.text)

dates
# Out:
# ['₹130 cr+Brokerage saved monthly',
#  '30 Lakh+Customers Connected Monthly',
#  '2 Lakh+New Listings Monthly']

# %%
#class="nb__2EQjN"
price = []

for i in soup.find_all('div',class_="nb__27n0h"):
    price.append(i.text)

price
# Out:
# ['₹130 cr+', '30 Lakh+', '2 Lakh+']

# %%
#class="heading-6 mb-1.5p"
b = []

for i in soup.find_all('div',class_="nb__3KVk4"):
    b.append(i.text)

b
# Out:
# ['Lowest PricePackers & Movers',
#  'New OffersPay rent',
#  'Flat 30% offRental Agreement',
#  'Click & Earn',
#  'NewPainting & Cleaning',
#  'NoBroker For NRIs']

# %%
houses = soup.find_all('div', )

# %%
titles= []
locations = []
areas = []
emis = []
prices = []

for house in houses:
        title = house.find('div', class_='heading-6').text
        location = house.find('div', class_=).text
        area = house.find('div', class_=).text
        emi = house.find('div', class_='font-semi-bold heading-6', text='EMI').find_next('div').text
        price = house.find('div', class_=).text

        titles.append(title)
        areas.append(area)
        emis.append(emi)
        prices.append(price)
# Out:
#   Cell In[139], line 9
#     location = house.find('div', class_=).text
#                                         ^
# SyntaxError: invalid syntax

# %%
titles
# Out:
# []

# %%
areas
# Out:
# []

# %% [markdown]
# QUESTION NO : 4

# %%
page = requests.get('https://www.bewakoof.com/bestseller?sort=popular')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <head>
# <meta content="4d8KRpUCzf-ghquF_HLNphibw_xRvUS3kAvzpnF2KlA" name="google-site-verification"/>
# <meta content="-TTsyPFCOB4bQlMHawiO4oZGcGX9pxqenB_NZNhhhgA" name="google-site-verification"/>
# <meta content="wQa0CQvt7fd2VIoa9qhkevhvwuBvhRwiaB3hVizI9OY" name="google-site-verification"/>
# <meta content="o7KS3-fVt15m4Cc1HeYh5HIpv532A4FvvYQzIf-LnsQ" name="google-site-verification"/>
# <link href="https://images.bewakoof.com" rel="preconnect"/>
# <link href="https://images.bewakoof.com" rel="dns-prefetch"/>
# <link href="https://static.bewakoof.com" rel="preconnect"/>
# <link href="https://static.bewakoof.com" rel="dns-prefetch"/>
# <link href="https://cdn.polyfill.io" rel="preconnect"/>
# <link href="https://cdn.polyfill.io" rel="dns-prefetch"/>
# <link href="https//www.googletagmanager.com" rel="preconnect"/>
# <link href="https//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
# ...

# %%
name = []

for i in soup.find_all('div',class_="productNaming bkf-ellipsis"):
    name.append(i.text)

name
# Out:
# ["bewakoof x star warsMen's Black Storm Trooper Graphic Printed Oversized T-shirt",
#  "Bewakoof®Men's Red Hunter Graphic Printed Oversized T-shirt",
#  "Bewakoof®Men's Grey Oversized Parachute Pants",
#  "Bewakoof®Women's Orange Skool Graphic Printed Boyfriend T-shirt",
#  "bewakoof x marvelMen's Brown Most Wanted Graphic Printed Oversized T-shirt",
#  "Bewakoof Air® 1.0Men's Black Oversized Cargo Joggers",
#  "Bewakoof®Men's Sky Blue Joggers",
#  "Bewakoof®Men's Green Joggers",
#  "Bewakoof Air® 1.0Men's Grey Oversized Joggers",
#  "Bewakoof®Men's Blue Stoned Panda Graphic Printed Oversized T-shirt"]

# %%
price = []

for i in soup.find_all('span',class_="discountedPriceText clr-p-black   false  "):
    price.append(i.text)

price
# Out:
# []

# %%
price = []

for i in soup.find_all('div',class_="productPriceBox d-flex align-items-end  false"):
    price.append(i.text)


price
# Out:
# []

# %%
images = []

for i in soup.find_all('img',class_="productImg"):
    images.append(i['data-src'])

images
# Out:
# []
